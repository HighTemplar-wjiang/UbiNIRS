# %%
import sys
sys.path.append("../../utils/nirs_estimators")
from predicts import NIRSEstimator, ModelType

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
model = NIRSEstimator("../trained/RFC", "../untrained/RFC", ModelType.classification)

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=200)
colors = ["red", "blue"]

idx = 0
for key, values in model.data_bins.items():    
    for item in values:
        ax.plot(item, label=key, color=colors[idx])
    idx += 1
fig.legend()
